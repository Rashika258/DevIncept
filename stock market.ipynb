# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
df = pd.read_csv('nse-tata-global-beverages-limited.csv')

# %%
df.head()
# Out:
#          Date    Open    High     Low    Last   Close  Total Trade Quantity  \
# 0  2018-10-08  208.00  222.25  206.85  216.00  215.15             4642146.0
# 1  2018-10-05  217.00  218.60  205.90  210.25  209.20             3519515.0
# 2  2018-10-04  223.50  227.80  216.15  217.25  218.20             1728786.0
# 3  2018-10-03  230.00  237.50  225.75  226.45  227.60             1708590.0
# 4  2018-10-01  234.55  234.60  221.05  230.30  230.90             1534749.0
#
#    Turnover (Lacs)
# 0         10062.83
# 1          7407.06
# 2          3815.79
# 3          3960.27
# 4          3486.05

# %%
df.describe()
# Out:
#               Open         High          Low         Last        Close  \
# count  1235.000000  1235.000000  1235.000000  1235.000000  1235.000000
# mean    168.954858   171.429069   166.402308   168.736356   168.731053
# std      51.499145    52.436761    50.542919    51.587384    51.544928
# min     103.000000   104.600000   100.000000   102.600000   102.650000
# 25%     137.550000   138.925000   135.250000   137.175000   137.225000
# 50%     151.500000   153.250000   149.500000   151.200000   151.100000
# 75%     169.000000   172.325000   166.700000   169.100000   169.500000
# max     327.700000   328.750000   321.650000   325.950000   325.750000
#
#        Total Trade Quantity  Turnover (Lacs)
# count          1.235000e+03      1235.000000
# mean           2.604151e+06      4843.166502
# std            2.277028e+06      5348.919832
# min            1.001800e+05       128.040000
# 25%            1.284482e+06      1801.035000
# 50%            1.964885e+06      3068.510000
# ...

# %%
df.shape
# Out:
# (1235, 8)

# %%
df.columns
# Out:
# Index(['Date', 'Open', 'High', 'Low', 'Last', 'Close', 'Total Trade Quantity',
#        'Turnover (Lacs)'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1235 entries, 0 to 1234
# Data columns (total 8 columns):
# Date                    1235 non-null object
# Open                    1235 non-null float64
# High                    1235 non-null float64
# Low                     1235 non-null float64
# Last                    1235 non-null float64
# Close                   1235 non-null float64
# Total Trade Quantity    1235 non-null float64
# Turnover (Lacs)         1235 non-null float64
# dtypes: float64(7), object(1)
# memory usage: 77.3+ KB

# %%
df.corr()
# Out:
#                           Open      High       Low      Last     Close  \
# Open                  1.000000  0.998956  0.998776  0.997662  0.997704
# High                  0.998956  1.000000  0.998728  0.999130  0.999159
# Low                   0.998776  0.998728  1.000000  0.999008  0.999065
# Last                  0.997662  0.999130  0.999008  1.000000  0.999963
# Close                 0.997704  0.999159  0.999065  0.999963  1.000000
# Total Trade Quantity  0.367503  0.388798  0.361695  0.381269  0.380801
# Turnover (Lacs)       0.587026  0.605907  0.582446  0.599575  0.599155
#
#                       Total Trade Quantity  Turnover (Lacs)
# Open                              0.367503         0.587026
# High                              0.388798         0.605907
# Low                               0.361695         0.582446
# Last                              0.381269         0.599575
# Close                             0.380801         0.599155
# ...

# %%
df.sum()
# Out:
# Date                    2018-10-082018-10-052018-10-042018-10-032018-1...
# Open                                                               208659
# High                                                               211715
# Low                                                                205507
# Last                                                               208389
# Close                                                              208383
# Total Trade Quantity                                          3.21613e+09
# Turnover (Lacs)                                               5.98131e+06
# dtype: object

# %%
plt.figure(figsize=(15,10))
df.corr()
sns.heatmap(df.corr(), annot=True, cmap='YlGnBu')

# %%
df.isnull().sum()
# Out:
# Date                    0
# Open                    0
# High                    0
# Low                     0
# Last                    0
# Close                   0
# Total Trade Quantity    0
# Turnover (Lacs)         0
# dtype: int64

# %%
plt.figure(figsize=(45,20))
df.hist(figsize=(20,10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x00000252434A9908>,
# ...
#       dtype=object)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
# Counting distinct observations
df.nunique()
# Out:
# Date                    1235
# Open                     799
# High                     863
# Low                      854
# Last                     865
# Close                    893
# Total Trade Quantity    1234
# Turnover (Lacs)         1231
# dtype: int64

# %%
sns.scatterplot(x='Open',y='Close',data=df,hue='Total Trade Quantity')

# %%
sns.scatterplot(x='High',y='Low',data=df,hue='Total Trade Quantity')

# %%
# Shuffle your dataset 
shuffle_df = df.sample(frac=1)

# Define a size for your train set 
train_size = int(0.8 * len(df))

# Split your dataset 
train = shuffle_df[:train_size]
test = shuffle_df[train_size:]

# %%
plt.scatter(train.Open, train.High, color='green')
plt.xlabel("Open")
plt.ylabel("High")
plt.show()

# %%
plt.scatter(train.Open, train.Low, color='green')
plt.xlabel("Open")
plt.ylabel("Low")
plt.show()

# %%
plt.scatter(train.Close, train.High, color='green')
plt.xlabel("Close")
plt.ylabel("High")
plt.show()

# %%
plt.scatter(train.Close, train.Low, color='green')
plt.xlabel("Close")
plt.ylabel("Low")
plt.show()
